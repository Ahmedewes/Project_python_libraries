# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmedewes/Project_python_libraries/blob/main/pythooon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import numpy as np
#import pandas as pd

hgsdfbfnsd,mfl
